# %%
# Data set
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv 
import pandas as pd

# %%
pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
read_head = pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")

# %%
read_head.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
read_head.tail(5)
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
df_0= read_head.head(25)

# %%
df_0
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
df_0.to_json('test_0.jason')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            25 non-null     int64
#  1   quantity            25 non-null     int64
#  2   item_name           25 non-null     object
#  3   choice_description  18 non-null     object
#  4   item_price          25 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.1+ KB

# %%
df_0.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df_0.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
df0 = df_0.to_csv("chipotle.csv")

# %%
df1 = pd.read_csv('chipotle.csv',sep = ',')

# %%
df1
# Out:
#     Unnamed: 0  order_id  quantity                              item_name  \
# 0            0         1         1           Chips and Fresh Tomato Salsa
# 1            1         1         1                                   Izze
# 2            2         1         1                       Nantucket Nectar
# 3            3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4            4         2         2                           Chicken Bowl
# 5            5         3         1                           Chicken Bowl
# 6            6         3         1                          Side of Chips
# 7            7         4         1                          Steak Burrito
# 8            8         4         1                       Steak Soft Tacos
# 9            9         5         1                          Steak Burrito
# 10          10         5         1                    Chips and Guacamole
# 11          11         6         1                   Chicken Crispy Tacos
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.describe()
# Out:
#        Unnamed: 0   order_id   quantity
# count   25.000000  25.000000  25.000000
# mean    12.000000   6.240000   1.080000
# std      7.359801   3.677409   0.276887
# min      0.000000   1.000000   1.000000
# 25%      6.000000   3.000000   1.000000
# 50%     12.000000   6.000000   1.000000
# 75%     18.000000   9.000000   1.000000
# max     24.000000  12.000000   2.000000

# %%
df_0.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
type(df_0['item_price'])
# Out:
# pandas.core.series.Series

# %%
type(df_0['order_id'])
# Out:
# pandas.core.series.Series

# %%
df_0[['item_price']]
# Out:
#    item_price
# 0      $2.39
# 1      $3.39
# 2      $3.39
# 3      $2.39
# 4     $16.98
# 5     $10.98
# 6      $1.69
# 7     $11.75
# 8      $9.25
# 9      $9.25
# 10     $4.45
# 11     $8.75
# 12     $8.75
# 13    $11.25
# 14     $4.45
# 15     $2.39
# 16     $8.49
# 17     $8.49
# 18     $2.18
# 19     $8.75
# 20     $4.45
# 21     $8.99
# 22     $3.39
# 23    $10.98
# 24     $3.39

# %%
df_0[df_0['item_price']==max(df_0['item_price'])]
# Out:
#    order_id  quantity         item_name  \
# 8         4         1  Steak Soft Tacos
# 9         5         1     Steak Burrito
#
#                                   choice_description item_price
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
df_0[df_0['item_price']==min(df_0['item_price'])]
# Out:
#    order_id  quantity      item_name choice_description item_price
# 6         3         1  Side of Chips                NaN     $1.69

# %%
g1=df_0.groupby('item_price')

# %%
g1=g1.sum()

# %%
g1 = g1.sort_values(['quantity'],ascending=False)

# %%
g1.head(5)
# Out:
#             order_id  quantity
# item_price
# $3.39             25         4
# $2.39             10         3
# $4.45             22         3
# $8.75             22         3
# $10.98            15         2

# %%
dollar_rmv = lambda x : float(x[1:-1])

# %%
df_0[df_0.item_price'==df_0[item_price.apply(dollar_rmv)]]
# Out:
#   File "<ipython-input-83-584108e0d058>", line 1
#     df_0[df_0.item_price'==df_0[item_price.apply(dollar_rmv)]]
#                                                               ^
# SyntaxError: EOL while scanning string literal

# %%
df_new = df_0.item_price.replace('$','',regex=True).astype(float)

# %%
df_new
# Out:
# 0      2.39
# 1      3.39
# 2      3.39
# 3      2.39
# 4     16.98
# 5     10.98
# 6      1.69
# 7     11.75
# 8      9.25
# 9      9.25
# 10     4.45
# 11     8.75
# 12     8.75
# 13    11.25
# 14     4.45
# 15     2.39
# 16     8.49
# 17     8.49
# 18     2.18
# 19     8.75
# 20     4.45
# 21     8.99
# 22     3.39
# 23    10.98
# 24     3.39
# Name: item_price, dtype: float64

# %%
df_0.item_price=df_new
# Out:
# C:\Users\pvenugo\Anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_0
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt", sep = ' ')
# Out:
#                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors_Light       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
txt=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt", sep = ' ')

# %%
newtext = txt.to_csv('text.csv', index=False)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
txt.head()
# Out:
#           name  calories  sodium  alcohol  cost
# 0    Budweiser       144      15      4.7  0.43
# 1      Schlitz       151      19      4.9  0.43
# 2    Lowenbrau       157      15      0.9  0.48
# 3  Kronenbourg       170       7      5.2  0.73
# 4     Heineken       152      11      5.0  0.77

# %%
pwd()
# Out:
# 'C:\\FSD\\iNeuron\\jpytr_ex\\Notes_Notebooks\\Untitled Folder'
